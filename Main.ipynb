# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithroger/TTL-Project-Voice-Recognition-/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 2: Import libraries
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization
import joblib

# %%
# Step 2: Import libraries
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization
import joblib

# Step 3: Set your base directory inside Google Drive
# Update base_dir to the correct path
base_dir = '/content/drive/MyDrive/TTL'
voice_dir = os.path.join(base_dir, 'Voice')
model_dir = os.path.join(base_dir, 'models')

# Step 4: Load metadata
metadata = pd.read_csv(os.path.join(voice_dir, 'frames_metadata.csv'))
print("Metadata columns:", metadata.columns)
print(metadata.head())
# Out:
# Metadata columns: Index(['frame_name', 'fsID', 'start', 'end', 'salience', 'fold', 'classId',
#        'Label'],
#       dtype='object')
#           frame_name  fsID  start   end  salience  fold  classId   Label
# 0  Voice_frame_0.wav     0    0.0   5.0         1     1        0  Yogesh
# 1  Voice_frame_1.wav     1    5.0  10.0         1     1        0  Yogesh
# 2  Voice_frame_2.wav     2   10.0  15.0         1     1        0  Yogesh
# 3  Voice_frame_3.wav     3   15.0  20.0         1     1        0  Yogesh
# 4  Voice_frame_4.wav     4   20.0  25.0         1     1        0  Yogesh

# %%
def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, sr=44100)
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40, fmax=8000)
        chroma = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
        mel = librosa.feature.melspectrogram(y=audio, sr=sample_rate)
        contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate)
        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sample_rate)

        features = np.hstack((
            np.mean(mfccs.T, axis=0),
            np.mean(chroma.T, axis=0),
            np.mean(mel.T, axis=0),
            np.mean(contrast.T, axis=0),
            np.mean(tonnetz.T, axis=0)
        ))
        return features
    except Exception as e:
        print(f"Error processing {file_name}: {e}")
        return None

# Step 6: Extract features and labels
features = []
labels = []

for index, row in metadata.iterrows():
    file_path = os.path.join(voice_dir, f'fold{row["fold"]}', row["frame_name"])

    if not os.path.exists(file_path):
        print(f"File does not exist: {file_path}")
        continue

    print(f"Processing file: {file_path}")
    feature = extract_features(file_path)

    if feature is not None:
        features.append(feature)
        labels.append(row["Label"])
    else:
        print(f"Failed to extract features from {file_path}")

if len(labels) == 0:
    raise ValueError("No labels found. Ensure the audio files are accessible and features are being extracted correctly.")

X = np.array(features)
y = np.array(labels)

# Step 7: Encode labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Step 8: Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state=42)

# Step 9: Build model
model = Sequential()
model.add(Dense(512, input_shape=(X_train.shape[1],)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(len(le.classes_)))
model.add(Activation('softmax'))

# Step 10: Compile model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# Step 11: Train model (reduce epochs for testing)
history = model.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_test, y_test), verbose=1)

# Step 12: Evaluate model
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_0.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_1.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_2.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_3.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_4.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_5.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_6.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_7.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_8.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_9.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_10.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_11.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_12.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_13.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_14.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_15.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_16.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_17.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_18.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_19.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_20.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_21.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_22.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_23.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_24.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_25.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_26.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_27.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_28.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_29.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_30.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_31.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_32.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_33.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_34.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_35.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_36.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_37.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_38.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_39.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_40.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_41.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_42.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_43.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_44.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_45.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_46.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_47.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_48.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_49.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_50.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_51.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_52.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_53.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_54.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_55.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_56.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_57.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_58.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_59.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_60.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_61.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_62.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_63.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_64.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_65.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_66.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_67.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_68.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_69.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_70.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_71.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_72.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_73.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_74.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_75.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_76.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_77.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_78.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_79.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_80.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_81.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_82.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_83.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_84.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_85.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_86.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_87.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_88.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_89.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_90.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_91.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_92.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_93.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_94.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame_95.wav
# Processing file: /content/drive/MyDrive/TTL/Voice/fold1/Voice_frame
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.4566 - loss: 1.5648 - val_accuracy: 0.5051 - val_loss: 4.9426
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8162 - loss: 0.5489 - val_accuracy: 0.5859 - val_loss: 2.6180
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8879 - loss: 0.3271 - val_accuracy: 0.5152 - val_loss: 1.7588
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9535 - loss: 0.1432 - val_accuracy: 0.5556 - val_loss: 1.4096
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9658 - loss: 0.0995 - val_accuracy: 0.6566 - val_loss: 0.9421
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9638 - loss: 0.1320 - val_accuracy: 0.8485 - val_loss: 0.3951
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9613 - loss: 0.1263 - val_accuracy: 0.9495 - val_loss: 0.1059
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9719 - loss: 0.0849 - val_accuracy: 0.9596 - val_loss: 0.0879
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9546 - loss: 0.1343 - val_accuracy: 0.9293 - val_loss: 0.1313
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9961 - loss: 0.0425 - val_accuracy: 0.9798 - val_loss: 0.0539
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9863 - loss: 0.0658 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9884 - loss: 0.0539 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9760 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9812 - loss: 0.0576 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9892 - loss: 0.0383 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9764 - loss: 0.0528 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9923 - loss: 0.0386 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9943 - loss: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9815 - loss: 0.0695 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9812 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0028
# Test loss: 0.0028441930189728737 / Test accuracy: 1.0

# %%
# Step 7: Encode labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Step 8: Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state=42)

# Step 9: Build model
model = Sequential()
model.add(Dense(512, input_shape=(X_train.shape[1],)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(len(le.classes_)))
model.add(Activation('softmax'))

# Step 10: Compile model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# Step 11: Train model (reduce epochs for testing)
history = model.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_test, y_test), verbose=1)

# Step 12: Evaluate model
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.4459 - loss: 1.6485 - val_accuracy: 0.3939 - val_loss: 5.1773
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8331 - loss: 0.4081 - val_accuracy: 0.5960 - val_loss: 2.1000
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8876 - loss: 0.3129 - val_accuracy: 0.5152 - val_loss: 1.6791
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9689 - loss: 0.1242 - val_accuracy: 0.5657 - val_loss: 1.3669
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9242 - loss: 0.2146 - val_accuracy: 0.5657 - val_loss: 2.1752
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9499 - loss: 0.1476 - val_accuracy: 0.6263 - val_loss: 1.2333
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9702 - loss: 0.0985 - val_accuracy: 0.8182 - val_loss: 0.5221
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9787 - loss: 0.0670 - val_accuracy: 0.8788 - val_loss: 0.3835
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9823 - loss: 0.0697 - val_accuracy: 0.9293 - val_loss: 0.2654
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9738 - loss: 0.0807 - val_accuracy: 0.9293 - val_loss: 0.1241
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9712 - loss: 0.0801 - val_accuracy: 0.9495 - val_loss: 0.1079
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9914 - loss: 0.0519 - val_accuracy: 0.9495 - val_loss: 0.1341
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9955 - loss: 0.0331 - val_accuracy: 0.9798 - val_loss: 0.0496
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9820 - loss: 0.0620 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9847 - loss: 0.0528 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9883 - loss: 0.0349 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9845 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9875 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9772 - loss: 0.0550 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0020
# Test loss: 0.00200350908562541 / Test accuracy: 1.0

# %%
# ... (previous code) ...

# Step 13: Save model and LabelEncoder
model.save(os.path.join(model_dir, 'Voice_recognition.h5'))  # Corrected file name
joblib.dump(le, os.path.join(model_dir, 'Voice_recognition.pkl'))  # Corrected file name

print("Model and LabelEncoder have been saved successfully.")

# Step 14: Predict function
def predict_sound_label(file_name):
    feature = extract_features(file_name)
    if feature is None:
        print(f"Unable to extract features from {file_name}")
        return None

    feature = feature.reshape(1, -1)
    predicted_vector = model.predict(feature)
    predicted_label = le.inverse_transform(np.argmax(predicted_vector, axis=1))
    return predicted_label[0]

# Step 15: Test with a sample file
test_file = os.path.join(voice_dir, 'fold3', 'sushan_frame_0.wav')  # Check if 'fold3' exists and contains the file
if os.path.exists(test_file):
    predicted_label = predict_sound_label(test_file)
    print(f"The predicted label for the sound is: {predicted_label}")
else:
    print(f"Error: Test file not found at {test_file}. Please ensure the file exists and the path is correct.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and LabelEncoder have been saved successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# The predicted label for the sound is: Sushan
